# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       3 print("CUDA available:", torch.cuda.is_available())
#       4 print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
#
# File ~/miniconda3/envs/torch/lib/python3.10/site-packages/torch/__init__.py:49
#      41     return False
#      44 from torch._utils import (
#      45     _functionalize_sync as _sync,
#      46     _import_dotted_name,
#      47     classproperty,
#      48 )
# ---> 49 from torch._utils_internal import (
#      50     get_file_path,
#      51     prepare_multiprocessing_environment,
#      52     profiler_allow_cudagraph_cupti_lazy_reinit_cuda12,
#      53     USE_GLOBAL_DEPS,
#      54     USE_RTLD_GLOBAL_WITH_LIBTORCH,
#      55 )
#      56 from torch.torch_version import __version__ as __version__
#      59 if TYPE_CHECKING:
#
# ImportError: cannot import name 'profiler_allow_cudagraph_cupti_lazy_reinit_cuda12' from 'torch._utils_internal' (/home/sougato97/miniconda3/envs/torch/lib/python3.10/site-packages/torch/_utils_internal.py)
